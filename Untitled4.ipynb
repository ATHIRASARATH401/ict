# %% [markdown]
# <a href="https://colab.research.google.com/github/ATHIRASARATH401/ict/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/Data-Science-Jobs.csv')

# %%
df.head()
# Out:
#    Position                                          Job Title  \
# 0         1                    Associate Stop Loss Underwriter
# 1         2                            Manager of Data Science
# 2         3                        Senior Data Product Manager
# 3         4                           Oncology Nurse Navigator
# 4         5  Head of Artificial Intelligence – Americas Region
#
#                 Company Name        Location                          Salary  \
# 0  The Insurance Center\n2.7    Onalaska, WI    $57K - $84K (Glassdoor est.)
# 1        Nuvative, Inc.\n3.4     Wichita, KS  $106K - $157K (Glassdoor est.)
# 2         ProviderTrust\n4.2   Nashville, TN  $105K - $141K (Glassdoor est.)
# 3         Inizio Engage\n3.6    Portland, OR    $90K - $113K (Employer est.)
# 4              Covestro\n3.6  Pittsburgh, PA   $89K - $148K (Glassdoor est.)
#
#    Date                                               Logo  \
# 0  30d+  https://media.glassdoor.com/sql/453835/the-ins...
# ...

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/MainakRepositor/Datasets/master/Gold%20Rates/daily_gold_rate.csv')

# %%
df.head()
# Out:
#          Date     USD     EUR     GBP      INR      AED    CNY
# 0  1985-01-01  308.30  402.45  266.01  3825.85  1134.42    NaN
# 1  1985-01-02  305.50  401.49  266.00  3787.05  1134.42    NaN
# 2  1985-01-03  302.30  397.08  262.76  3718.88  1107.67    NaN
# 3  1985-01-04  303.15  397.15  262.58  3759.64  1118.21    NaN
# 4  1985-01-07  298.25  392.55  261.17  3741.23  1091.58  835.8
